# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
apo_mean_acc = np.array([67.4625, 74.8875, 83.86666667, 86.275, 87.5375])
apo_std_acc = np.array([0.555840205, 0.625, 0.880814017, 0.963068014, 0.385951206])
rand_mean_acc = np.array([66.275, 72.05, 78.9625, 83.6375, 84.9])
rand_std_acc = np.array([0.992051746, 0.940744386, 0.694472222, 0.759797122, 0.63900965])
x = np.array([500, 1000, 2000, 3000, 4000])

# %%
plt.plot(x, apo_mean_acc, label='APO (Ours)', markersize=8, color='blue', marker='o')
plt.fill_between(x, apo_mean_acc - apo_std_acc, apo_mean_acc + apo_std_acc, alpha=0.4, color='blue')
plt.plot(x, rand_mean_acc, label='Random', markersize=8, color='orange', marker='o')
plt.fill_between(x, rand_mean_acc - rand_std_acc, rand_mean_acc + rand_std_acc, alpha=0.4, color='orange')
plt.legend(fontsize=13)
plt.grid()
plt.xlabel('Total Number of Samples', fontsize=13)
plt.ylabel('Reward Accuracy', fontsize=13)
plt.title('Gemma : Reward Accuracy vs Train Samples (Small Epochs)', fontsize=14)
plt.savefig('./results/Gemma-Reward-Accuracy-Small-Epochs', dpi=800)
plt.show()

# %%
apo_mean_acc = np.array([66.8625, 77.425, 94.2625, 96.0875, 97.5375])
apo_std_acc = np.array([0.523410292, 0.29011492, 0.686021137, 0.39869579, 0.792017466])
rand_mean_acc = np.array([66.2875, 74, 83.5125, 88.65, 92.1875])
rand_std_acc = np.array([1.225680083, 0.402077936, 0.728440114, 0.595818764, 0.661280324])

# %%
plt.plot(x, apo_mean_acc, label='APO (Ours)', markersize=8, color='blue', marker='o')
plt.fill_between(x, apo_mean_acc - apo_std_acc, apo_mean_acc + apo_std_acc, alpha=0.4, color='blue')
plt.plot(x, rand_mean_acc, label='Random', markersize=8, color='orange', marker='o')
plt.fill_between(x, rand_mean_acc - rand_std_acc, rand_mean_acc + rand_std_acc, alpha=0.4, color='orange')
plt.legend(fontsize=13)
plt.grid()
plt.xlabel('Total Number of Samples', fontsize=13)
plt.ylabel('Reward Accuracy', fontsize=13)
plt.title('Gemma : Reward Accuracy vs Train Samples (Large Epochs)', fontsize=14)
plt.savefig('./results/Gemma-Reward-Accuracy-Large-Epochs', dpi=800)
plt.show()

# %%
np.mean(np.array(df_apo['reward']) - np.array(df_rand['reward']))
# Out:
# 0.030951212

# %%
plt.hist(np.array(df_apo['reward']) - np.array(df_rand['reward']), alpha=0.6, bins=50)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_apo = pd.read_csv('./output/Anthropic_small_Gemma_apo_le_reward.csv')
df_rand = pd.read_csv('./output/Anthropic_small_Gemma_random_le_reward.csv')
df_apo_2 = pd.read_csv('./output/Anthropic_small_Gemma_apo_le_reward_2.csv')
df_rand_2 = pd.read_csv('./output/Anthropic_small_Gemma_random_le_reward_2.csv')
df_chosen = pd.read_csv('./output/Anthropic_small_Gemma_chosen_le_reward.csv')
df_chosen_2 = pd.read_csv('./output/Anthropic_small_Gemma_chosen_le_reward_2.csv')

# %%
reward_apo = np.array(pd.concat([df_apo['reward'], df_apo_2['reward']]))
reward_rand = np.array(pd.concat([df_rand['reward'], df_rand_2['reward']]))
reward_chosen = np.array(pd.concat([df_chosen['reward'], df_chosen_2['reward']]))

# %%
plt.hist(reward_apo, alpha=0.6, label='APO (Ours)', bins=50)
plt.hist(reward_rand, alpha=0.6, label='Random', bins=50)
plt.legend()
plt.show()

# %%
sns.kdeplot(reward_rand, color='orange', label='Random', fill=True, alpha=0.45)
sns.kdeplot(reward_apo, color='b', label='APO (Ours)', fill=True, alpha=0.45)
plt.xlabel('Rewards')
plt.ylabel('Density')
plt.grid()
plt.show()
# Out:
# /home/t-dasnirjhar/anaconda3/envs/trl/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/t-dasnirjhar/anaconda3/envs/trl/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
np.mean(reward_apo > reward_chosen) * 100
# Out:
# 87.2

# %%
np.mean(reward_rand > reward_chosen) * 100
# Out:
# 85.2

# %%
np.mean(reward_apo > reward_rand) * 100
# Out:
# 52.400000000000006

# %%
df_apo = pd.read_csv('./output/Anthropic_small_Gemma_apo_le_reward_2k_v4.csv')
df_rand = pd.read_csv('./output/Anthropic_small_Gemma_random_le_reward_2k_v4.csv')
df_sft = pd.read_csv('./output/Anthropic_small_Gemma_sft_le_reward_2k_v4.csv')

# %%
print(len(df_apo))
# Out:
# 1989

# %%
reward_apo = np.array(df_apo['reward'])
reward_rand = np.array(df_rand['reward'])
reward_sft = np.array(df_sft['reward'])

# %%
sns.kdeplot(reward_rand, color='orange', label='Random', fill=True, alpha=0.45)
# sns.kdeplot(reward_sft, color='g', label='SFT', fill=True, alpha=0.45)
sns.kdeplot(reward_apo, color='b', label='APO (Ours)', fill=True, alpha=0.45)
plt.xlabel('Rewards', fontsize=13)
plt.ylabel('Density', fontsize=13)
plt.legend(fontsize=13, loc='upper left')
plt.title('Reward Distribution after PPO', fontsize=15)
plt.grid()
plt.savefig('./results/Reward-Distribution_no_SFT.png', dpi=800)
plt.show()
# Out:
# /home/t-dasnirjhar/anaconda3/envs/trl/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/t-dasnirjhar/anaconda3/envs/trl/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
np.mean(reward_apo > reward_sft) * 100
# Out:
# 52.43841126194068

# %%
np.mean(reward_rand > reward_sft) * 100
# Out:
# 40.67370537958773

# %%
plt.bar(['APO (Ours)', 'Random'], [np.mean(reward_apo > reward_sft) * 100, np.mean(reward_rand > reward_sft) * 100], color=['blue', 'orange'])
#plt.xlabel('Method', fontsize=13)
plt.xticks(fontsize=13)
plt.ylabel('Win Rate', fontsize=13)
plt.title('Win Rate compared to SFT', fontsize=15)
plt.grid(axis='y')
plt.savefig('./results/Win_rate_vs_SFT_2k.png', dpi=800)
plt.show()

# %%
plt.bar(['APO (Ours)', 'Random'], [71, 100 - 71], color=['blue', 'orange'])
#plt.xlabel('Method', fontsize=13)
plt.xticks(fontsize=13)
plt.ylabel('Win Rate', fontsize=13)
plt.title('APO vs Random - Win Rate', fontsize=15)
plt.grid(axis='y')
plt.savefig('./results/Win_rate_200.png', dpi=800)
plt.show()
